# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
df = pd.read_csv('sfh.csv')

# %%
df.head(25)
# Out:
#     RegionID                          RegionName  SizeRank   1996-04  \
# 0     102001                       United States         0  106409.0
# 1     394913                        New York, NY         1  189376.0
# 2     753899  Los Angeles-Long Beach-Anaheim, CA         2  192140.0
# 3     394463                         Chicago, IL         3  162321.0
# 4     394514               Dallas-Fort Worth, TX         4  113140.0
# 5     394974                    Philadelphia, PA         5  121051.0
# 6     394692                         Houston, TX         6  110533.0
# 7     395209                      Washington, DC         7  188263.0
# 8     394856           Miami-Fort Lauderdale, FL         8  125543.0
# 9     394347                         Atlanta, GA         9  122098.0
# 10    394404                          Boston, MA        10  176662.0
# 11    395057                   San Francisco, CA        11  253840.0
# 12    394532                         Detroit, MI        12  101029.0
# ...

# %%
df.shape
# Out:
# (914, 290)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 914 entries, 0 to 913
# Columns: 290 entries, RegionID to 2020-02
# dtypes: float64(261), int64(28), object(1)
# memory usage: 2.0+ MB

# %%
df.describe()
# Out:
#             RegionID    SizeRank        1996-04        1996-05        1996-06  \
# count     914.000000  914.000000     433.000000     437.000000     438.000000
# mean   414882.884026  456.500000   92673.882217   93220.608696   93340.769406
# std     83873.071740  263.993371   44286.102285   44476.332664   44436.382415
# min    102001.000000    0.000000   26243.000000   26284.000000   26327.000000
# 25%    394547.250000  228.250000   62068.000000   62799.000000   62734.750000
# 50%    394801.500000  456.500000   83412.000000   83845.000000   83962.000000
# 75%    395048.750000  684.750000  110684.000000  111109.000000  111137.750000
# max    753929.000000  913.000000  317176.000000  313312.000000  309355.000000
#
#              1996-07        1996-08        1996-09        1996-10  \
# count     439.000000     439.000000     440.000000     440.000000
# mean    93641.628702   93872.913440   94073.056818   94313.931818
# std     44444.069025   44495.710421   44507.543293   44591.759474
# ...

# %%
df.fillna(0)
# Out:
#      RegionID                          RegionName  SizeRank   1996-04  \
# 0      102001                       United States         0  106409.0
# 1      394913                        New York, NY         1  189376.0
# 2      753899  Los Angeles-Long Beach-Anaheim, CA         2  192140.0
# 3      394463                         Chicago, IL         3  162321.0
# 4      394514               Dallas-Fort Worth, TX         4  113140.0
# ..        ...                                 ...       ...       ...
# 909    394767                          Lamesa, TX       909       0.0
# 910    753874                           Craig, CO       910   63465.0
# 911    394968                           Pecos, TX       911       0.0
# 912    395188                          Vernon, TX       912       0.0
# 913    394743                       Ketchikan, AK       913       0.0
#
#       1996-05   1996-06   1996-07   1996-08   1996-09   1996-10  ...  2019-05  \
# ...

# %%
df.fillna(df.mean())
# Out:
#      RegionID                          RegionName  SizeRank        1996-04  \
# 0      102001                       United States         0  106409.000000
# 1      394913                        New York, NY         1  189376.000000
# 2      753899  Los Angeles-Long Beach-Anaheim, CA         2  192140.000000
# 3      394463                         Chicago, IL         3  162321.000000
# 4      394514               Dallas-Fort Worth, TX         4  113140.000000
# ..        ...                                 ...       ...            ...
# 909    394767                          Lamesa, TX       909   92673.882217
# 910    753874                           Craig, CO       910   63465.000000
# 911    394968                           Pecos, TX       911   92673.882217
# 912    395188                          Vernon, TX       912   92673.882217
# 913    394743                       Ketchikan, AK       913   92673.882217
#
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of      RegionID                          RegionName  SizeRank   1996-04  \
# 0      102001                       United States         0  106409.0
# 1      394913                        New York, NY         1  189376.0
# 2      753899  Los Angeles-Long Beach-Anaheim, CA         2  192140.0
# 3      394463                         Chicago, IL         3  162321.0
# 4      394514               Dallas-Fort Worth, TX         4  113140.0
# ..        ...                                 ...       ...       ...
# 909    394767                          Lamesa, TX       909       NaN
# 910    753874                           Craig, CO       910   63465.0
# 911    394968                           Pecos, TX       911       NaN
# 912    395188                          Vernon, TX       912       NaN
# 913    394743                       Ketchikan, AK       913       NaN
#
#       1996-05   1996-06   1996-07   1996-08   1996-09   1996-10  ...  2019-05  \
# ...

# %%
df.dropna(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 433 entries, 0 to 910
# Columns: 290 entries, RegionID to 2020-02
# dtypes: float64(261), int64(28), object(1)
# memory usage: 984.4+ KB

# %%
df = pd.read_csv('bottomtier.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Columns: 290 entries, RegionID to 2020-02
# dtypes: float64(105), int64(184), object(1)
# memory usage: 115.7+ KB

# %%
sns.boxplot(df.RegionID)

# %%
df[df.Size_Rank>=00]
# Out:
#     RegionID       Region_nameName  Size_Rank   1996_04   1996_05   1996-06  \
# 0          9            California          1   93822.0   93675.0   93560.0
# 1         54                 Texas          2   53776.0   53870.0   53960.0
# 2         43              New York          3   61800.0   61760.0   61741.0
# 3         14               Florida          4   57624.0   57746.0   57882.0
# 4         21              Illinois          5   67680.0   67478.0   67369.0
# 5         47          Pennsylvania          6   48860.0   48819.0   48805.0
# 6         44                  Ohio          7   46854.0   47026.0   47185.0
# 7         30              Michigan          8   42607.0   42900.0   43195.0
# 8         16               Georgia          9   53490.0   53694.0   53905.0
# 9         36        North Carolina         10   57430.0   57670.0   57939.0
# 10        40            New Jersey         11   92920.0   92754.0   92625.0
# ...

# %%
df.Size_Rank.hist()

# %%
df.RegionID.unique
# Out:
# <bound method Series.unique of 0      9
# 1     54
# 2     43
# 3     14
# 4     21
# 5     47
# 6     44
# 7     30
# 8     16
# 9     36
# 10    40
# 11    56
# 12    59
# 13    26
# 14    22
# 15     8
# 16    53
# 17    32
# 18    27
# 19    60
# 20    31
# 21    10
# 22     4
# 23    51
# 24    25
# 25    24
# 26    46
# 27    45
# 28    11
# 29    19
# 30    34
# 31     6
# 32    23
# 33    55
# 34    42
# 35    41
# 36    61
# 37    38
# 38    20
# 39    18
# 40    28
# 41    39
# 42    50
# 43    35
# 44    13
# 45    52
# 46     3
# 47    37
# 48    58
# 49    12
# 50    62
# Name: RegionID, dtype: int64>

# %%
df.describe()
# Out:
#         RegionID  Size_Rank        1996_04        1996_05        1996-06  \
# count  51.000000  51.000000      47.000000      47.000000      47.000000
# mean   33.137255  26.000000   63885.829787   63959.170213   64048.531915
# std    17.260382  14.866069   24166.125907   24093.773469   24018.394582
# min     3.000000   1.000000   26092.000000   26121.000000   26156.000000
# 25%    19.500000  13.500000   45396.000000   45627.500000   45905.500000
# 50%    34.000000  26.000000   58962.000000   59187.000000   59470.000000
# 75%    46.500000  38.500000   83914.000000   84134.000000   84322.500000
# max    62.000000  51.000000  141251.000000  140298.000000  139279.000000
#
#              1996-07        1996-08        1996-09        1996-10  \
# count      47.000000      47.000000      47.000000      47.000000
# mean    64140.085106   64265.340426   64398.510638   64548.319149
# std     23955.778221   23925.667895   23912.497694   23898.401838
# ...

# %%
df = pd.read_csv('ESSdata.csv')

# %%
sns.violinplot(x=df.happy, y=df.agea)

# %%
df.head(2)
# Out:
#   cntry  idno  year  tvtot  ppltrst  pplfair  pplhlp  happy  sclmeet  sclact  \
# 0    CH   5.0     6    3.0      3.0     10.0     5.0    8.0      5.0     4.0
# 1    CH  25.0     6    6.0      5.0      7.0     5.0    9.0      3.0     2.0
#
#    gndr  agea  partner
# 0   2.0  60.0      1.0
# 1   2.0  59.0      1.0
